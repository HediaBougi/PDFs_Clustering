# %% [markdown]
# # Load Libraries

# %%
import re
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt


import nltk
import nltk.data
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize 

from yellowbrick.text import TSNEVisualizer

from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA

from sklearn.metrics.pairwise import pairwise_distances
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('in.tsv', sep="\t", header=None, names = ['filename', 'keys', 'text_djvu', 'text_tesseract', 'text_textract', 'text_best'])

# %%
display(df.head())
print('Shape:', df.shape)
print('Type:\n', df.dtypes)
# Out:
#                                filename  \
# 0  008482cf51383c158b54e593cfa5fbf7.pdf
# 1  009fab39d746267b6de8428366fe4b02.pdf
# 2  01c7fd563327947c68abdd9717ef228d.pdf
# 3  01d804edf76bec4912d2466908a60889.pdf
# 4  01e4461b059e707b7d8276b3d2b80b71.pdf
#
#                                                 keys  \
# 0  address__post_town address__postcode address__...
# 1  address__post_town address__postcode address__...
# 2  address__post_town address__postcode address__...
# 3  address__post_town address__postcode address__...
# 4  address__post_town address__postcode address__...
#
#                                            text_djvu  \
# 0  TAR\n1\nAugust 2016\nTrustees' Annual Report f...
# 1  \fAnnual Report 2015-2017 July, 2017\nStepping...
# 2  Promoting Independent Living\nCelebrating new\...
# 3  Annual Repor t 8\nAccounts 2017/18\nYear ended...
# 4  The Greenway Centre\n(Registered charity, numb...
#
#                                       text_tesseract  \
# 0  CHARITY Trustees’' Annual Report for the perio...
# 1  \n; Na {if anv)\n{\noA el\nC 3 QIC [1€d C\nf (...
# 2  54 S ke *\nB\n \nWelcome to our Annual\nReport...
# 3  Annual Report &\nAccounts 2017//183\nYear ende...
# 4  The Greenway Centre\n(Registered charity, numb...
#
#                                        text_textract  \
# 0  CHARITY\nTrustees' Annual Report for the perio...
# 1  Charity Name\nNo lif anv)\nStepping Stone Thea...
# 2  Promoting Independent Living\nAbility\nAbility...
# 3  Annua Report &\nAccounts 2017/18\nYear ended 3...
# 4  The Greenway Centre\n(Registered charity, numb...
#
#                                            text_best
# 0  TAR\n1\nAugust 2016\nTrustees' Annual Report f...
# 1  \n; Na {if anv)\n{\noA el\nC 3 QIC [1€d C\nf (...
# 2  54 S ke *\nB\n \nWelcome to our Annual\nReport...
# 3  Annual Repor t 8\nAccounts 2017/18\nYear ended...
# 4  The Greenway Centre\n(Registered charity, numb...
# Shape: (1729, 6)
# Type:
#  filename          object
# keys              object
# text_djvu         object
# text_tesseract    object
# text_textract     object
# text_best         object
# dtype: object

# %% [markdown]
# # Data Preprocessing

# %%
# Drop NaN values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1683, 6)

# %%
df = df.replace(r'\\n',' ', regex=True)
df = df.replace(r'[^\w\s]',' ', regex=True)
df = df.replace(r'<.*?>',' ', regex=True)
df = df.replace(r'\[[^]]*\]',' ', regex=True)

# %%
# Cleaning text and lower casing all words
for char in '_-.,\n':
    df['text_textract'] = df['text_textract'].replace(char,' ')
df['text_textract'] = df['text_textract'].str.lower()

# %%
df['text_textract']
# Out:
# 0       charity trustees' annual report for the period...
# 1       charity name no lif anv) stepping stone theatr...
# 2       promoting independent living ability ability a...
# 3       annua report & accounts 2017/18 year ended 31 ...
# 4       the greenway centre (registered charity, numbe...
#                               ...
# 1724    charity trustees' annual report for the period...
# 1725    the gordon russell trust charity no. 326446 tr...
# 1726    friends of ezra charity no charity (if any) 11...
# 1727    caspari foundation (company number 3815700) (r...
# 1728    registered company number: 09623674 (england a...
# Name: text_textract, Length: 1683, dtype: object

# %%
#df.loc[:, ["text_textract"]].iloc[1682].values

# %% [markdown]
# --------------------------------------------------------
# #### OCR-ed documents transformed by Tesseract
# (meaning both new and old OCR engines were used simultaneously, and language and pixel density were forced for better results)

# %% [markdown]
# # Word Count

# %%
word_count = df['text_textract'].str.split(expand=True).stack().value_counts()

# %%
print('Word Count:\n', word_count)
# Out:
# Word Count:
#  the        652215
# and        328590
# of         328408
# to         250560
# in         180471
#             ...
# cotth           1
# snitch          1
# 34760           1
# cmdy            1
# ooooddc         1
# Length: 91587, dtype: int64

# %% [markdown]
# # Stemmimg and Tokenization

# %%
# Load english stop words
stopwords = nltk.corpus.stopwords.words('english')

# %%
# Load nltk's SnowballStemmer as variable 'stemmer'
stemmer = SnowballStemmer("english")

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

# %% [markdown]
# # TF-IDFVectorizer

# %% [markdown]
#  => With Tfidfvectorizer, you will do all three steps at once.
#  - Under the hood, it computes the word counts, IDF values, and TF-IDF scores all using the same dataset.

# %%
# Define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=0.2, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

# %% [markdown]
# ### Features names

# %%
terms = tfidf_vectorizer.get_feature_names()
#print(terms)

# %% [markdown]
# # TF-IDF Matrix

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text_textract'])
# Out:
# /home/becode/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
print('TF-IDF Matrix shape:\n', tfidf_matrix.shape)
print('TF-IDF Matrix type:\n', type(tfidf_matrix))
# Out:
# TF-IDF Matrix shape:
#  (1683, 2166)
# TF-IDF Matrix type:
#  <class 'scipy.sparse.csr.csr_matrix'>

# %% [markdown]
# ### Cosine Similarity

# %%
cosine_similarity(tfidf_matrix[0:1], tfidf_matrix)
# Out:
# array([[1.        , 0.32983187, 0.11217933, ..., 0.39337057, 0.27175079,
#         0.18494628]])

# %% [markdown]
# ### Pairwise Similarity

# %%
pairwise_similarity = tfidf_matrix * tfidf_matrix.T
pairwise_similarity
# Out:
# <1683x1683 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2832489 stored elements in Compressed Sparse Row format>

# %%
#Heatmap of cosine similarity
np.random.seed(0)
sns.set_theme()

ax = sns.heatmap(pairwise_similarity.toarray())

# %% [markdown]
# # K-Means

# %% [markdown]
# => In practice, the k-means algorithm is very fast (one of the fastest clustering algorithms available), but it falls in local minima. That’s why it can be useful to restart it several times.

# %% [markdown]
# ### Elbew Method

# %% [markdown]
# inertia_float
# Sum of squared distances of samples to their closest cluster center.

# %%
Sum_of_squared_distances = []
K = range(2,30)

for k in K:
    kmeans = KMeans(n_clusters=k, max_iter=200, n_init=10)
    kmeans = kmeans.fit(tfidf_matrix)
    Sum_of_squared_distances.append(kmeans.inertia_)

plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ### k=8

# %% [markdown]
# ‘k-means++’ : selects initial cluster centers for k-mean clustering in a smart way to speed up convergence.

# %%
k = 8
X = tfidf_matrix.toarray()

# %%
kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=400, n_init=20)
kmeans.fit(tfidf_matrix)#Learn the idf vector

# %%
y = kmeans.predict(X)

# %%
labels = kmeans.labels_.tolist()
print('Labels:\n',labels)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=200, cmap='coolwarm')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=400, alpha=0.5)

# %% [markdown]
# #### Clusters labels

# %%
df['labels'] = list(labels)

# %%
df_cl = pd.DataFrame(list(zip(df['filename'],labels)),columns = ['filename','cluster'])
print(df_cl.sort_values(by = ['cluster']))
# Out:
#                                   filename  cluster
# 362   335fee4e94532ccb3b8e245ddad1f63a pdf        0
# 1028  97f7db448093deb2835d6222319f7ab0 pdf        0
# 525   4aba73764d57d5ed9d930c029ce59a2b pdf        0
# 1449  dcb020106dc0aee55efd58715a502b73 pdf        0
# 1033  98c23700d1fa72a2501413686351895d pdf        0
# ...                                    ...      ...
# 475   434d8cbd69ce66562de57ea08f7dabc3 pdf        7
# 586   54191d47151386fc07b7ea3a206e6629 pdf        7
# 1615  f3517f4df60d9d78214d45400f3f3f71 pdf        7
# 1376  d00a400741e182bc2a41c0b9b7e511d1 pdf        7
# 1227  b9063cd6254c6c0b0fdb4f1cd3d9e024 pdf        7
#
# [1683 rows x 2 columns]

# %%
#pca = PCA(n_components=k).fit(X)
#KM = KMeans(n_clusters=k, init=pca.components_, max_iter=400, n_init=1)

# %% [markdown]
# ### k=10

# %% [markdown]
# ‘random’: choose n_clusters observations (rows) at random from data for the initial centroids.

# %% [markdown]
# Fits transformer to X and y returns a transformed version of X.

# %% [markdown]
# X_new: ndarray array of shape (n_samples, n_features_new)
# -->Transformed array.

# %%
k = 10
X = tfidf_matrix.toarray()

KM = KMeans(n_clusters=k, init='random', max_iter=1000, n_init=20)

#Compute k-means clustering.
KM.fit(tfidf_matrix)

# Predict the closest cluster each sample in X belongs to.
y = KM.predict(tfidf_matrix)

# Compute clustering and transform X to cluster-distance space. 
# Fit to data, then transform it.
X_new = KM.fit_transform(tfidf_matrix)

labels = KM.labels_.tolist()
#print('Labels:\n',labels)

# %%
plt.scatter(X_new[:, 8], X_new[:, 4], c=y, s=200, cmap='viridis')

# %% [markdown]
# #### K-Means cluster centers

# %%
centers = KM.cluster_centers_
plt.scatter(centers[:, 8], centers[:, 4], c='black', s=400, alpha=0.5)

# %% [markdown]
# #### Clusters labels

# %%
df['labels'] = list(labels)

# %%
df['labels'].value_counts()
# Out:
# 3    388
# 0    366
# 4    299
# 6    239
# 7    123
# 5    120
# 2    103
# 1     45
# Name: labels, dtype: int64

# %%
#df[df['labels'] == 1 ]

# %%
#df.loc[:, ["text_textract"]].iloc[658].values

# %% [markdown]
# ### K_Means Clutering Visualisation

# %%
#Create the visualizer and draw the vectors
tsne = TSNEVisualizer()
#Fit tsne on tfidf scores
tsne.fit(X, labels, metric='cosine')
#Visualise
tsne.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:title={'center':'TSNE Projection of 1683 Documents'}>

# %% [markdown]
# ## Word Cloud

# %%
from wordcloud import WordCloud
result={'cluster':labels,'pdf':df['text_textract']}
result=pd.DataFrame(result)
for k in range(0,k):
    s=result[result.cluster==k]
    text=s['pdf'].str.cat(sep=' ')
    text=text.lower()
    text=' '.join([word for word in text.split()])
    wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="grey").generate(text)
    print('Cluster: {}'.format(k))
    #print('Titles')
    titles=df_cl[df_cl.cluster==k]['filename']         
    #print(titles.to_string(index=False))
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
# Out:
# Cluster: 0
# Cluster: 1
# Cluster: 2
# Cluster: 3
# Cluster: 4
# Cluster: 5
# Cluster: 6
# Cluster: 7

# %% [markdown]
# # DBSCAN

# %% [markdown]
# DBSCAN - Density-Based Spatial Clustering of Applications with Noise. Finds core samples of high density and expands clusters from them. Good for data which contains clusters of similar density.

# %%
# Define dataset
X = tfidf_matrix.toarray()

# Define the model
db = DBSCAN(eps=0.4, min_samples=5, metric='euclidean', algorithm='ball_tree', leaf_size=30).fit(X)

# %%
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)

# Plot result
# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [1, 1, 1, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 18
# Estimated number of noise points: 1577

# %% [markdown]
# #### Clusters labels

# %%
df['labels'] = list(labels)

# %%
df['labels'].value_counts()
# Out:
# -1     1577
#  1       17
#  9        9
#  7        5
#  0        5
#  2        5
#  3        5
#  4        5
#  5        5
#  6        5
#  16       5
#  15       5
#  17       5
#  10       5
#  11       5
#  12       5
#  13       5
#  14       5
#  8        5
# Name: labels, dtype: int64

# %% [markdown]
# #### Verifying clusters

# %%
df[df['labels']==7]
# Out:
#                                   filename  \
# 273   25ef7f0d940e51cf00b61869e7f702d8 pdf
# 795   71bdbd1916d460617f5f5a1b7158d651 pdf
# 1212  b03732b0d7414ef7604f442b5752c501 pdf
# 1543  e3aee543b9cd1311eccdf6d82b109eda pdf
# 1589  e9532f4f698b3e518dbf311e075b3695 pdf
#
#                                                    keys  \
# 273   address__post_town address__postcode address__...
# 795   address__post_town address__postcode address__...
# 1212  address__post_town address__postcode address__...
# 1543  address__post_town address__postcode address__...
# 1589  address__post_town address__postcode address__...
#
#                                               text_djvu  \
# 273   BRIGHTONWESTDIVISIONGUIDES ANNUALREPORTFORTHEY...
# 795   BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
# 1212  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
# 1543  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
# 1589  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
#
#                                          text_tesseract  \
# 273   BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
# 795   BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
# 1212  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
# 1543  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
# 1589  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...
#
#                                           text_textract  \
# 273   brighton west division guides annual report fo...
# 795   brighton west division guides annual report fo...
# 1212  brighton west division guides annual report fo...
# 1543  brighton west division guides annual report fo...
# 1589  brighton west division guides annual report fo...
#
#                                               text_best  labels
# 273   BRIGHTONWESTDIVISIONGUIDES ANNUALREPORTFORTHEY...       7
# 795   BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...       7
# 1212  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...       7
# 1543  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...       7
# 1589  BRIGHTON WEST DIVISION GUIDES ANNUAL REPORT FO...       7

# %%
df[df['labels']==0]
# Out:
#                                   filename  \
# 14    030d80fea4fc1ac8d3d8f366ec92bd21 pdf
# 462   401026f1b90e03bddca32972d47a1b94 pdf
# 598   530352185b91c7876cdc99f5c9fa1344 pdf
# 1369  c93ab85fbaa95a2a4ad0ccb51e1d0196 pdf
# 1704  fc2ee8284700d4fa58925ef83af8cf73 pdf
#
#                                                    keys  \
# 14    address__post_town address__postcode address__...
# 462   address__post_town address__postcode address__...
# 598   address__post_town address__postcode address__...
# 1369  address__post_town address__postcode address__...
# 1704  address__post_town address__postcode address__...
#
#                                               text_djvu  \
# 14    Charity Registered No r083995  Company Registe...
# 462   METHODIST HOMES REPORT AND FINANCIAL STATEMENT...
# 598   METHODIST HOMES REPORT AND FINANCIAL STATEMENT...
# 1369  METHODIST HOMES REPORT AND FINANCIAL STATEMENT...
# 1704  1 D H z c   D D r r L   r L         O j Z H H ...
#
#                                          text_tesseract  \
# 14     METHODIST HOMES    PORT AND ACCOUNTS 31 March...
# 462   METHODIST HOMES REPORT AND FINANCIAL STATEMENT...
# 598   METHODIST HOMES REPORT AND FINANCIAL STATEMENT...
# 1369  METHODIST HOMES REPORT AND FINANCIAL STATEMENT...
# 1704  S B R R R   METHODIST HOMES REPORT AND ACCOUNT...
#
#                                           text_textract  \
# 14    charity first  8 sep 20m accounes recenved met...
# 462   methodist homes report and financial statement...
# 598   methodist homes report and financial statement...
# 1369  methodist homes report and financial statement...
# 1704  methodist homes report and accounts 31 march 2...
#
#                                               text_best  labels
# 14    Charity Registered No r083995  Company Registe...       0
# 462   METHODIST HOMES REPORT AND FINANCIAL STATEMENT...       0
# 598   METHODIST HOMES REPORT AND FINANCIAL STATEMENT...       0
# 1369  METHODIST HOMES REPORT AND FINANCIAL STATEMENT...       0
# 1704  1 D H z c   D D r r L   r L         O j Z H H ...       0

# %%
df[df['labels']==2]
# Out:
#                                   filename  \
# 71    0aac0eba00811f0552259efcbdc9234d pdf
# 938   85c3b1b1b914c49fb67e8b0b58ea16fe pdf
# 1449  d5208563d1d6b6f4c186ecfa06a4dfe3 pdf
# 1558  e4f98ba78a6d3334b53785a537128638 pdf
# 1679  f691f1cc66ea7288e3cf7a233fc793f2 pdf
#
#                                                    keys  \
# 71    address__post_town address__postcode address__...
# 938   address__post_town address__postcode address__...
# 1449  address__post_town address__postcode address__...
# 1558  address__post_town address__postcode address__...
# 1679  address__post_town address__postcode address__...
#
#                                               text_djvu  \
# 71    COMPANY NUMBER  3752751 CHARITY NUMBER  115194...
# 938   COMPANY NUMBER  3752751 CHARITY NUMBER  115194...
# 1449  COMPANY NUMBER  3752751 CHARITY NUMBER  115194...
# 1558  COMPANY NUMBER  3752751 CHARITY NUMBER  115194...
# 1679  COMPANY NUMBER  3752751 CHARITY NUMBER  115194...
#
#                                          text_tesseract  \
# 71    COMPANY NUMBER  3752751 CHARITY NUMBER  115194...
# 938   COMPANY NUMBER  3752751 CHARITY NUMBER  115194...
# 1449  S CALICO HOMES LIMITED Report and Financial St...
# 1558  COMPANY NUMBER  3752751 CHARITY NUMBER  115198...
# 1679  COMPANY NUMBER  3752751 CHARITY NUMBER  115194...
#
#                                           text_textract  \
# 71    company number  3752751 charity number  115194...
# 938   company number  3752751 charity number  115194...
# 1449  company number  3752751 charity number  115194...
# 1558  company number  3752751 charity number  115194...
# 1679  company number  3752751 charity number  115194...
#
#                                               text_best  labels
# 71    COMPANY NUMBER  3752751 CHARITY NUMBER  115194...       2
# 938   COMPANY NUMBER  3752751 CHARITY NUMBER  115194...       2
# 1449  S CALICO HOMES LIMITED Report and Financial St...       2
# 1558  COMPANY NUMBER  3752751 CHARITY NUMBER  115194...       2
# 1679  COMPANY NUMBER  3752751 CHARITY NUMBER  115194...       2

# %%
df[df['labels']==9]
# Out:
#                                   filename  \
# 353   3162e7993554acd7fb45eaf96d549e43 pdf
# 430   3bc8da7d893b2b861036b0342caefb26 pdf
# 449   3deb2ad3880982e86fb3b672b930a7e2 pdf
# 980   8b5d842d702fc464643162e387b152f6 pdf
# 1208  afde656c306d7125611bc9755b9a9116 pdf
# 1260  b9063cd6254c6c0b0fdb4f1cd3d9e024 pdf
# 1437  d324272fbe15179003fed9c634e68086 pdf
# 1588  e94807c9f87166b963e1cfa27ccd930b pdf
# 1626  ee34f8ebc2902e5e15daa22b97c0305b pdf
#
#                                                    keys  \
# 353   address__post_town address__postcode address__...
# 430   address__post_town address__postcode address__...
# 449   address__post_town address__postcode address__...
# 980   address__post_town address__postcode address__...
# 1208  address__post_town address__postcode address__...
# 1260  address__post_town address__postcode address__...
# 1437  address__post_town address__postcode address__...
# 1588  address__post_town address__postcode address__...
# 1626  address__post_town address__postcode address__...
#
#                                               text_djvu  \
# 353   Charity Registration No  1102588 Company Regis...
# 430   Ec PW  Charity Registration t4o  1076483 Compa...
# 449   Charity Registration No  1076483 Company Regis...
# 980   Charity Registration N Company Registration No...
# 1208  Charity Registration No  1076483 Company Regis...
# 1260  Charity Registration No  U 76483 Company Regis...
# 1437  Charity Registration No  1102588 Company Regis...
# 1588  Charity Registration No  1076483 Company Regis...
# 1626  Charity Registration No  1102588 Company Regis...
#
#                                          text_tesseract  \
# 353   Charity Registration No  1102588 Company Regis...
# 430   Charity Registration No  1076483 Company Regis...
# 449   Charity Registration No  1076483 Company Regis...
# 980     Charity Registration No 1102538   Company Re...
# 1208  Charity Registration No  1076483 Company Regis...
# 1260  CHan vy comMt tya Charity Registration No  107...
# 1437  Charity Registration No  1102588 Company Regis...
# 1588  Charity Registration No  1076483 Company Regis...
# 1626  Charity Registration No  1102588 Company Regis...
#
#                                           text_textract  \
# 353   charity registration no  1102588 company regis...
# 430   extenal charity registration no  1076483 compa...
# 449   charity registration no  1076483 company regis...
# 980   charity registration no  1102588 company regis...
# 1208  charity registration no  1076483 company regis...
# 1260  chanty connimta charity registration no  10764...
# 1437  charity registration no  1102588 company regis...
# 1588  charity registration no  1076483 company regis...
# 1626  charity registration no  1102588 company regis...
#
#                                               text_best  labels
# 353   Charity Registration No  1102588 Company Regis...       9
# 430   Ec PW  Charity Registration t4o  1076483 Compa...       9
# 449   Charity Registration No  1076483 Company Regis...       9
# 980   Charity Registration N Company Registration No...       9
# 1208  Charity Registration No  1076483 Company Regis...       9
# 1260  Charity Registration No  U 76483 Company Regis...       9
# 1437  Charity Registration No  1102588 Company Regis...       9
# 1588  Charity Registration No  1076483 Company Regis...       9
# 1626  Charity Registration No  1102588 Company Regis...       9

# %% [markdown]
# # HDBSCAN

# %%
import hdbscan

# %%
hdbscan.dist_metrics.METRIC_MAPPING
# Out:
# {'euclidean': hdbscan.dist_metrics.EuclideanDistance,
#  'l2': hdbscan.dist_metrics.EuclideanDistance,
#  'minkowski': hdbscan.dist_metrics.MinkowskiDistance,
#  'p': hdbscan.dist_metrics.MinkowskiDistance,
#  'manhattan': hdbscan.dist_metrics.ManhattanDistance,
#  'cityblock': hdbscan.dist_metrics.ManhattanDistance,
#  'l1': hdbscan.dist_metrics.ManhattanDistance,
#  'chebyshev': hdbscan.dist_metrics.ChebyshevDistance,
#  'infinity': hdbscan.dist_metrics.ChebyshevDistance,
#  'seuclidean': hdbscan.dist_metrics.SEuclideanDistance,
#  'mahalanobis': hdbscan.dist_metrics.MahalanobisDistance,
#  'wminkowski': hdbscan.dist_metrics.WMinkowskiDistance,
#  'hamming': hdbscan.dist_metrics.HammingDistance,
#  'canberra': hdbscan.dist_metrics.CanberraDistance,
#  'braycurtis': hdbscan.dist_metrics.BrayCurtisDistance,
#  'matching': hdbscan.dist_metrics.MatchingDistance,
#  'jaccard': hdbscan.dist_metrics.JaccardDistance,
#  'dice': hdbscan.dist_metrics.DiceDistance,
#  'kulsinski': hdbscan.dist_metrics.KulsinskiDistance,
#  'rogerstanimoto': hdbscan.dist_metrics.RogersTanimotoDistance,
#  'russellrao': hdbscan.dist_metrics.RussellRaoDistance,
#  'sokalmichener': hdbscan.dist_metrics.SokalMichenerDistance,
#  'sokalsneath': hdbscan.dist_metrics.SokalSneathDistance,
#  'haversine': hdbscan.dist_metrics.HaversineDistance,
#  'cosine': hdbscan.dist_metrics.ArccosDistance,
#  'arccos': hdbscan.dist_metrics.ArccosDistance,
#  'pyfunc': hdbscan.dist_metrics.PyFuncDistance}

# %%
hdb = hdbscan.HDBSCAN(algorithm='best', alpha=1.0, approx_min_span_tree=True, gen_min_span_tree=False, leaf_size=40)

# %%
X = tfidf_matrix.toarray()

hdb.fit(tfidf_matrix)

print('Labels:\n', hdb.labels_)
print('Largest cluster label:\n', hdb.labels_.max())
print(hdb.probabilities_)
# Out:
# HDBSCAN()

# %% [markdown]
# ## HDBSCAN Visualisation

# %%
projection = TSNE().fit_transform(X)
plt.scatter(*projection.T, c=hdb.labels_, s=20, cmap='coolwarm')

# %% [markdown]
# ## Outliers Visualisation

# %%
# Set outlier threshold at 90th percentile
threshold = pd.Series(hdb.outlier_scores_).quantile(0.9)

# Filter to make outlier list
outliers = np.where(hdb.outlier_scores_ > threshold)[0]

# Plot data in grey
#plt.scatter(*projection.T, s=20, linewidth=0, c='gray', alpha=0.25)

# Plot outliers in blue
print('Number of outliers:', len(outliers))
plt.scatter(*projection[outliers].T, s=20, linewidth=0, c='blue', alpha=0.5)
# Out:
# Number of outliers: 169

# %%
distance_matrix = pairwise_distances(tfidf_matrix)
clusterer = hdbscan.HDBSCAN(metric='precomputed')
clusterer.fit(distance_matrix)
clusterer.labels_
# Out:
# array([ 7, -1, -1, ..., 10,  4, -1])

# %%
hdb.condensed_tree_

# %%
hdb.condensed_tree_.plot()
# Out:
# <AxesSubplot:ylabel='$\\lambda$ value'>

# %%
hdb.condensed_tree_.plot(select_clusters=True, selection_palette=sns.color_palette('deep', 20))
# Out:
# <AxesSubplot:ylabel='$\\lambda$ value'>

# %% [markdown]
# => We can now see the hierarchy as a dendrogram, the width (and color) of each branch representing the number of points in the cluster at that level.

# %%
hdb.single_linkage_tree_.plot()
# Out:
# <AxesSubplot:ylabel='distance'>
